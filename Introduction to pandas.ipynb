# %%
import pandas as pd

# %%
# 2 main datatypes

series = pd.Series(['BMW','TOyota','Honda'])

# %%
# series = 1-dimensional

# %%
colors = pd.Series(['red', 'blue','white'])
colors.describe()
# Out:
# count         3
# unique        3
# top       white
# freq          1
# dtype: object

# %%
# DataFrame = 2-dimensional

car_data = pd.DataFrame({'Car make':series, 'Color':colors})
car_data
# Out:
#   Car make  Color
# 0      BMW    red
# 1   TOyota   blue
# 2    Honda  white

# %%
# import data


car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe

car_sales.to_csv('exported-car-sales.csv', index=False)

# %%
exported_car_sales = pd.read_csv('exported-car-sales.csv')

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute

car_sales.dtypes

## Function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# give statistical information about numerical columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.median()
# Out:
# Odometer (KM)    57369.0
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Price'].sum()
# Out:
# 7645000

# %%
car_sales['Doors'].mean()
# Out:
# 4.0

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.tail(4)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc

animals = pd.Series(['cat','dog','bird','panda','snake'], index=[0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position whereas loc refers to index
animals.iloc[3]
# Out:
# 'panda'

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals.loc[:9]

# %%
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000 ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Doors'], car_sales['Make'])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
car_sales['Odometer (KM)'].hist()

# %%
car_sales['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# dataframe['amount'] = dataframe['amount'].str.replace('[\$\,\.]','').astype(int)

car_sales = pd.read_csv('car-sales.csv')
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','').astype(int)
car_sales['Price'] = car_sales['Price']/100
car_sales['Price'].plot(kind='bar')

# %%
car_sales
car_sales.Price.plot()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv('car_sales_missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    4.0      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Doors'].fillna(car_sales_missing['Doors'].mean(), inplace=True)

# %%
car_sales_missing['Price'] = car_sales_missing['Price'].str.replace('[\$\,\,]','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-3a4bf877fbc5> in <module>
# ----> 1 car_sales_missing['Price'] = car_sales_missing['Price'].str.replace('[\$\,\,]','').astype(int)
#
# ~/Mwibutsa/learning/python/complete_ml_ds/sample_project/env/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/Mwibutsa/learning/python/complete_ml_ds/sample_project/env/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/Mwibutsa/learning/python/complete_ml_ds/sample_project/env/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/Mwibutsa/learning/python/complete_ml_ds/sample_project/env/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/Mwibutsa/learning/python/complete_ml_ds/sample_project/env/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White  150043.0    4.0   4000
# 1   Honda    Red   87899.0    4.0   5000
# 2  Toyota   Blue       NaN    3.0   7000
# 3     BMW  Black   11179.0    5.0  22000
# 4  Nissan  White  213095.0    4.0   3500
# 5  Toyota  Green       NaN    4.0   4500
# 6   Honda    NaN       NaN    4.0   7500
# 7   Honda   Blue       NaN    4.0    NaN
# 8  Toyota  White   60000.0    4.0    NaN
# 9     NaN  White   31600.0    4.0   9700

# %%
car_sales_missing[car_sales_missing['Price'].isnull()]
# Out:
#      Make Colour  Odometer  Doors Price
# 7   Honda   Blue       NaN    4.0   NaN
# 8  Toyota  White   60000.0    4.0   NaN

# %%
car_sales_missing['Price'] = pd.to_numeric(car_sales_missing['Price'], errors='coerce')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    4.0      NaN
# 9     NaN  White   31600.0    4.0   9700.0

# %%
car_sales_missing['Price'] = car_sales_missing['Price'].fillna(car_sales_missing['Price'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0   7900.0
# 8  Toyota  White   60000.0    4.0   7900.0
# 9     NaN  White   31600.0    4.0   9700.0

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 8  Toyota  White   60000.0    4.0   7900.0

# %%
car_sales_missing_dropped = car_sales_missing

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 8  Toyota  White   60000.0    4.0   7900.0

# %%
car_sales_missing= pd.read_csv('car_sales_missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Price'] = car_sales_missing['Price'].str.replace('[\$\,\,]','')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White  150043.0    4.0   4000
# 1   Honda    Red   87899.0    4.0   5000
# 2  Toyota   Blue       NaN    3.0   7000
# 3     BMW  Black   11179.0    5.0  22000
# 4  Nissan  White  213095.0    4.0   3500
# 5  Toyota  Green       NaN    4.0   4500
# 6   Honda    NaN       NaN    4.0   7500
# 7   Honda   Blue       NaN    4.0    NaN
# 8  Toyota  White   60000.0    NaN    NaN
# 9     NaN  White   31600.0    4.0   9700

# %%
car_sales_missing['Price'] = pd.to_numeric(car_sales_missing['Price'],errors='coerce')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   9700.0

# %%
car_sales_missing['Price'] = car_sales_missing['Price'].fillna(car_sales_missing['Price'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0   7900.0
# 8  Toyota  White   60000.0    NaN   7900.0
# 9     NaN  White   31600.0    4.0   9700.0

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   4000.0
# 1   Honda    Red   87899.000000    4.0   5000.0
# 2  Toyota   Blue   92302.666667    3.0   7000.0
# 3     BMW  Black   11179.000000    5.0  22000.0
# 4  Nissan  White  213095.000000    4.0   3500.0
# 5  Toyota  Green   92302.666667    4.0   4500.0
# 6   Honda    NaN   92302.666667    4.0   7500.0
# 7   Honda   Blue   92302.666667    4.0   7900.0
# 8  Toyota  White   60000.000000    NaN   7900.0
# 9     NaN  White   31600.000000    4.0   9700.0

# %%
car_sales_missing['Colour'] = car_sales_missing.fillna('Black')

# %%
car_sales_missing
# Out:
#      Make  Colour       Odometer  Doors    Price
# 0  Toyota  Toyota  150043.000000    4.0   4000.0
# 1   Honda   Honda   87899.000000    4.0   5000.0
# 2  Toyota  Toyota   92302.666667    3.0   7000.0
# 3     BMW     BMW   11179.000000    5.0  22000.0
# 4  Nissan  Nissan  213095.000000    4.0   3500.0
# 5  Toyota  Toyota   92302.666667    4.0   4500.0
# 6   Honda   Honda   92302.666667    4.0   7500.0
# 7   Honda   Honda   92302.666667    4.0   7900.0
# 8  Toyota  Toyota   60000.000000    NaN   7900.0
# 9     NaN   Black   31600.000000    4.0   9700.0

# %%
car_sales_missing_dropped =car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make  Colour       Odometer  Doors    Price
# 0  Toyota  Toyota  150043.000000    4.0   4000.0
# 1   Honda   Honda   87899.000000    4.0   5000.0
# 2  Toyota  Toyota   92302.666667    3.0   7000.0
# 3     BMW     BMW   11179.000000    5.0  22000.0
# 4  Nissan  Nissan  213095.000000    4.0   3500.0
# 5  Toyota  Toyota   92302.666667    4.0   4500.0
# 6   Honda   Honda   92302.666667    4.0   7500.0
# 7   Honda   Honda   92302.666667    4.0   7900.0

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# Column from series

seats_column = pd.Series([5,5,6,6,4])

# %%
# New column called seats
car_sales['Seats'] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    6.0
# 3     bmw  Black          11179      5  22000.0    6.0
# 4  nissan  White         213095      4   3500.0    4.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales['Seats'] = car_sales['Seats'].fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    6.0
# 3     bmw  Black          11179      5  22000.0    6.0
# 4  nissan  White         213095      4   3500.0    4.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
# Column from Python list

fuel_economy = [7.5, 9.2,5.0,9.6,8.7,7,6.8,9.1,10,9.6]
len(fuel_economy)
# Out:
# 10

# %%
car_sales['Fuel per 100KM'] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    6.0             5.0
# 3     bmw  Black          11179      5  22000.0    6.0             9.6
# 4  nissan  White         213095      4   3500.0    4.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             7.0
# 6   honda   Blue          45698      4   7500.0    5.0             6.8
# 7   honda   Blue          54738      4   7000.0    5.0             9.1
# 8  toyota  White          60000      4   6250.0    5.0            10.0
# 9  nissan  White          31600      4   9700.0    5.0             9.6

# %%
car_sales["Total fuel used (L)"] = car_sales['Odometer (KM)'] /100 * car_sales['Fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Create a column from a single value

car_sales['Number of wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    6.0             5.0
# 3     bmw  Black          11179      5  22000.0    6.0             9.6
# 4  nissan  White         213095      4   3500.0    4.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             7.0
# 6   honda   Blue          45698      4   7500.0    5.0             6.8
# 7   honda   Blue          54738      4   7000.0    5.0             9.1
# 8  toyota  White          60000      4   6250.0    5.0            10.0
# 9  nissan  White          31600      4   9700.0    5.0             9.6
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225            11253.225                 4
# 1         8086.708             8086.708                 4
# 2         1627.450             1627.450                 4
# 3         1073.184             1073.184                 4
# 4        18539.265            18539.265                 4
# 5         6944.910             6944.910                 4
# 6         3107.464             3107.464                 4
# 7         4981.158             4981.158                 4
# 8         6000.000             6000.000                 4
# 9         3033.600             3033.600                 4

# %%
car_sales['Passed road safety'] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    6.0             5.0
# 3     bmw  Black          11179      5  22000.0    6.0             9.6
# 4  nissan  White         213095      4   3500.0    4.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             7.0
# 6   honda   Blue          45698      4   7500.0    5.0             6.8
# 7   honda   Blue          54738      4   7000.0    5.0             9.1
# 8  toyota  White          60000      4   6250.0    5.0            10.0
# 9  nissan  White          31600      4   9700.0    5.0             9.6
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed road safety
# 0        11253.225            11253.225                 4                True
# 1         8086.708             8086.708                 4                True
# 2         1627.450             1627.450                 4                True
# 3         1073.184             1073.184                 4                True
# 4        18539.265            18539.265                 4                True
# 5         6944.910             6944.910                 4                True
# 6         3107.464             3107.464                 4                True
# 7         4981.158             4981.158                 4                True
# 8         6000.000             6000.000                 4                True
# 9         3033.600             3033.600                 4                True

# %%
car_sales = car_sales.drop('Total fuel used', axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    6.0             5.0
# 3     bmw  Black          11179      5  22000.0    6.0             9.6
# 4  nissan  White         213095      4   3500.0    4.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             7.0
# 6   honda   Blue          45698      4   7500.0    5.0             6.8
# 7   honda   Blue          54738      4   7000.0    5.0             9.1
# 8  toyota  White          60000      4   6250.0    5.0            10.0
# 9  nissan  White          31600      4   9700.0    5.0             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# 2             1627.450                 4                True
# 3             1073.184                 4                True
# 4            18539.265                 4                True
# 5             6944.910                 4                True
# 6             3107.464                 4                True
# 7             4981.158                 4                True
# 8             6000.000                 4                True
# 9             3033.600                 4                True

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3  7000.0    6.0             5.0
# 1   honda    Red          87899      4  5000.0    5.0             9.2
# 9  nissan  White          31600      4  9700.0    5.0             9.6
# 5  toyota  Green          99213      4  4500.0    5.0             7.0
# 0  toyota  White         150043      4  4000.0    5.0             7.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 2             1627.450                 4                True
# 1             8086.708                 4                True
# 9             3033.600                 4                True
# 5             6944.910                 4                True
# 0            11253.225                 4                True

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 3     bmw  Black          11179      5  22000.0    6.0             9.6
# 8  toyota  White          60000      4   6250.0    5.0            10.0
# 9  nissan  White          31600      4   9700.0    5.0             9.6
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 6   honda   Blue          45698      4   7500.0    5.0             6.8
# 4  nissan  White         213095      4   3500.0    4.0             8.7
# 7   honda   Blue          54738      4   7000.0    5.0             9.1
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 2  toyota   Blue          32549      3   7000.0    6.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             7.0
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 3             1073.184                 4                True
# 8             6000.000                 4                True
# 9             3033.600                 4                True
# 1             8086.708                 4                True
# 6             3107.464                 4                True
# 4            18539.265                 4                True
# 7             4981.158                 4                True
# 0            11253.225                 4                True
# 2             1627.450                 4                True
# 5             6944.910                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 9  Nissan  White          31600      4   $9,700.00
# 4  Nissan  White         213095      4   $3,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 6   Honda   Blue          45698      4   $7,500.00
# 3     BMW  Black          11179      5  $22,000.00
# 1   Honda    Red          87899      4   $5,000.00

# %%
# Only select 20% of data

car_sales_shuffled.sample(frac=0.1)
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 6  Honda   Blue          45698      4  $7,500.00

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota   Blue          32549      3   $7,000.00
# 1  Nissan  White          31600      4   $9,700.00
# 2  Nissan  White         213095      4   $3,500.00
# 3   Honda   Blue          54738      4   $7,000.00
# 4  Toyota  Green          99213      4   $4,500.00
# 5  Toyota  White         150043      4   $4,000.00
# 6  Toyota  White          60000      4   $6,250.00
# 7   Honda   Blue          45698      4   $7,500.00
# 8     BMW  Black          11179      5  $22,000.00
# 9   Honda    Red          87899      4   $5,000.00

# %%
car_sales_shuffled
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors       Price
# 0        0      2  Toyota   Blue          32549      3   $7,000.00
# 1        1      5  Toyota  Green          99213      4   $4,500.00
# 2        2      9  Nissan  White          31600      4   $9,700.00
# 3        3      8  Toyota  White          60000      4   $6,250.00
# 4        4      3     BMW  Black          11179      5  $22,000.00
# 5        5      0  Toyota  White         150043      4   $4,000.00
# 6        6      7   Honda   Blue          54738      4   $7,000.00
# 7        7      4  Nissan  White         213095      4   $3,500.00
# 8        8      6   Honda   Blue          45698      4   $7,500.00
# 9        9      1   Honda    Red          87899      4   $5,000.00

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x /1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White      93776.875      4   $4,000.00
# 1   Honda    Red      54936.875      4   $5,000.00
# 2  Toyota   Blue      20343.125      3   $7,000.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5  Toyota  Green      62008.125      4   $4,500.00
# 6   Honda   Blue      28561.250      4   $7,500.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      37500.000      4   $6,250.00
# 9  Nissan  White      19750.000      4   $9,700.00

# %%
car
