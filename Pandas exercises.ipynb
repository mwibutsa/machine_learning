# %%
import pandas as pd

# %%
colours = pd.Series(['Red','Green','Black'])

# %%
colours
# Out:
# 0      Red
# 1    Green
# 2    Black
# dtype: object

# %%
cars = pd.Series(['Toyota','BMW','Benz'])

# %%
cars
# Out:
# 0    Toyota
# 1       BMW
# 2      Benz
# dtype: object

# %%
cars_df = pd.DataFrame({'Type':cars, 'Color':colours})

# %%
cars_df
# Out:
#      Type  Color
# 0  Toyota    Red
# 1     BMW  Green
# 2    Benz  Black

# %%
car_sales = pd.read_csv('car-sales.csv')

# %%
cars_df.to_csv('cars_df.csv')

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Type    3 non-null      object
#  1   Color   3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
cars_df.describe()
# Out:
#        Type  Color
# count     3      3
# unique    3      3
# top     BMW  Black
# freq      1      1

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
type(cars_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(car_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
numbers  = pd.Series([1,2,3,4,5,89,12,34,45])

# %%
numbers.mean()
# Out:
# 21.666666666666668

# %%
numbers.sum()
# Out:
# 195

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.sample(frac=1).iloc[3]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        45698
# Doors                    4
# Price            $7,500.00
# Name: 6, dtype: object

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
dir(car_sales)
# Out:
# ['Colour',
#  'Doors',
#  'Make',
#  'Price',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
car_sales.groupby('Make').mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\,]','')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4000.00
# 1   Honda    Red          87899      4   5000.00
# 2  Toyota   Blue          32549      3   7000.00
# 3     BMW  Black          11179      5  22000.00
# 4  Nissan  White         213095      4   3500.00
# 5  Toyota  Green          99213      4   4500.00
# 6   Honda   Blue          45698      4   7500.00
# 7   Honda   Blue          54738      4   7000.00
# 8  Toyota  White          60000      4   6250.00
# 9  Nissan  White          31600      4   9700.00

# %%
car_sales['Price'] = pd.to_numeric(car_sales['Price']).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %% [markdown]
# ### Car sales Missing

# %%
car_sales_missing = pd.read_csv('car_sales_missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer']).mean()

# %%
car_sales_missing
# Out:
#      Make Colour      Odometer  Doors    Price  Odometer (KM)
# 0  Toyota  White  92302.666667    4.0   $4,000   92302.666667
# 1   Honda    Red  92302.666667    4.0   $5,000   92302.666667
# 2  Toyota   Blue  92302.666667    3.0   $7,000   92302.666667
# 3     BMW  Black  92302.666667    5.0  $22,000   92302.666667
# 4  Nissan  White  92302.666667    4.0   $3,500   92302.666667
# 5  Toyota  Green  92302.666667    4.0   $4,500   92302.666667
# 6   Honda    NaN  92302.666667    4.0   $7,500   92302.666667
# 7   Honda   Blue  92302.666667    4.0      NaN   92302.666667
# 8  Toyota  White  92302.666667    NaN      NaN   92302.666667
# 9     NaN  White  92302.666667    4.0   $9,700   92302.666667

# %%
car_sales_missing['Odometer (KM)']
# Out:
# 0    92302.666667
# 1    92302.666667
# 2    92302.666667
# 3    92302.666667
# 4    92302.666667
# 5    92302.666667
# 6    92302.666667
# 7    92302.666667
# 8    92302.666667
# 9    92302.666667
# Name: Odometer (KM), dtype: float64

# %%
# car_sales_missing.drop('Odometer (KM)', axis=1)

# %%
car_sales_missing
# Out:
#      Make Colour      Odometer  Doors    Price
# 0  Toyota  White  92302.666667    4.0   $4,000
# 1   Honda    Red  92302.666667    4.0   $5,000
# 2  Toyota   Blue  92302.666667    3.0   $7,000
# 3     BMW  Black  92302.666667    5.0  $22,000
# 4  Nissan  White  92302.666667    4.0   $3,500
# 5  Toyota  Green  92302.666667    4.0   $4,500
# 6   Honda    NaN  92302.666667    4.0   $7,500
# 7   Honda   Blue  92302.666667    4.0      NaN
# 8  Toyota  White  92302.666667    NaN      NaN
# 9     NaN  White  92302.666667    4.0   $9,700

# %%
car_sales_missing = car_sales_missing.dropna()

# %%
car_sales_missing
# Out:
#      Make Colour      Odometer  Doors    Price
# 0  Toyota  White  92302.666667    4.0   $4,000
# 1   Honda    Red  92302.666667    4.0   $5,000
# 2  Toyota   Blue  92302.666667    3.0   $7,000
# 3     BMW  Black  92302.666667    5.0  $22,000
# 4  Nissan  White  92302.666667    4.0   $3,500
# 5  Toyota  Green  92302.666667    4.0   $4,500

# %%
car_sales_missing['Seats'] = 5
# Out:
# <ipython-input-108-428bba19a7c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_missing['Seats'] = 5

# %%
car_sales_missing
# Out:
#      Make Colour      Odometer  Doors    Price  Seats
# 0  Toyota  White  92302.666667    4.0   $4,000      5
# 1   Honda    Red  92302.666667    4.0   $5,000      5
# 2  Toyota   Blue  92302.666667    3.0   $7,000      5
# 3     BMW  Black  92302.666667    5.0  $22,000      5
# 4  Nissan  White  92302.666667    4.0   $3,500      5
# 5  Toyota  Green  92302.666667    4.0   $4,500      5

# %%
engine_size = [1.3,1.5,2.3,4.5,3.4,3.9]

# %%
car_sales_missing['Engine size'] = engine_size
# Out:
# <ipython-input-111-0fdec90652dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_missing['Engine size'] = engine_size

# %%
car_sales_missing
# Out:
#      Make Colour      Odometer  Doors    Price  Seats  Engine size
# 0  Toyota  White  92302.666667    4.0   $4,000      5          1.3
# 1   Honda    Red  92302.666667    4.0   $5,000      5          1.5
# 2  Toyota   Blue  92302.666667    3.0   $7,000      5          2.3
# 3     BMW  Black  92302.666667    5.0  $22,000      5          4.5
# 4  Nissan  White  92302.666667    4.0   $3,500      5          3.4
# 5  Toyota  Green  92302.666667    4.0   $4,500      5          3.9

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales['Price per KM'] = car_sales['Odometer (KM)'] / car_sales['Price']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Price per KM
# 0  toyota  White         150043      4   4000     37.510750
# 1   honda    Red          87899      4   5000     17.579800
# 2  toyota   Blue          32549      3   7000      4.649857
# 3     bmw  Black          11179      5  22000      0.508136
# 4  nissan  White         213095      4   3500     60.884286
# 5  toyota  Green          99213      4   4500     22.047333
# 6   honda   Blue          45698      4   7500      6.093067
# 7   honda   Blue          54738      4   7000      7.819714
# 8  toyota  White          60000      4   6250      9.600000
# 9  nissan  White          31600      4   9700      3.257732

# %%
car_sales.drop('Price per KM' ,axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Price per KM
# 9  nissan  White          31600      4   9700      3.257732
# 5  toyota  Green          99213      4   4500     22.047333
# 3     bmw  Black          11179      5  22000      0.508136
# 2  toyota   Blue          32549      3   7000      4.649857
# 1   honda    Red          87899      4   5000     17.579800
# 0  toyota  White         150043      4   4000     37.510750
# 4  nissan  White         213095      4   3500     60.884286
# 6   honda   Blue          45698      4   7500      6.093067
# 7   honda   Blue          54738      4   7000      7.819714
# 8  toyota  White          60000      4   6250      9.600000

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Price per KM
# 8  toyota  White          60000      4   6250      9.600000
# 2  toyota   Blue          32549      3   7000      4.649857
# 6   honda   Blue          45698      4   7500      6.093067
# 4  nissan  White         213095      4   3500     60.884286
# 3     bmw  Black          11179      5  22000      0.508136
# 0  toyota  White         150043      4   4000     37.510750
# 9  nissan  White          31600      4   9700      3.257732
# 5  toyota  Green          99213      4   4500     22.047333
# 1   honda    Red          87899      4   5000     17.579800
# 7   honda   Blue          54738      4   7000      7.819714

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Price per KM
# 0  toyota  White          60000      4   6250      9.600000
# 1  toyota   Blue          32549      3   7000      4.649857
# 2   honda   Blue          45698      4   7500      6.093067
# 3  nissan  White         213095      4   3500     60.884286
# 4     bmw  Black          11179      5  22000      0.508136
# 5  toyota  White         150043      4   4000     37.510750
# 6  nissan  White          31600      4   9700      3.257732
# 7  toyota  Green          99213      4   4500     22.047333
# 8   honda    Red          87899      4   5000     17.579800
# 9   honda   Blue          54738      4   7000      7.819714

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Price per KM
# 0  toyota  White      93776.875      4   4000     37.510750
# 1   honda    Red      54936.875      4   5000     17.579800
# 2  toyota   Blue      20343.125      3   7000      4.649857
# 3     bmw  Black       6986.875      5  22000      0.508136
# 4  nissan  White     133184.375      4   3500     60.884286
# 5  toyota  Green      62008.125      4   4500     22.047333
# 6   honda   Blue      28561.250      4   7500      6.093067
# 7   honda   Blue      34211.250      4   7000      7.819714
# 8  toyota  White      37500.000      4   6250      9.600000
# 9  nissan  White      19750.000      4   9700      3.257732

# %%
car_sales = car_sales.rename(columns= {'Odometer (KM)':'Odometer (miles)'})

# %%
car_sales
# Out:
#      Make Colour  Odometer (miles)  Doors  Price  Price per KM
# 0  toyota  White         93776.875      4   4000     37.510750
# 1   honda    Red         54936.875      4   5000     17.579800
# 2  toyota   Blue         20343.125      3   7000      4.649857
# 3     bmw  Black          6986.875      5  22000      0.508136
# 4  nissan  White        133184.375      4   3500     60.884286
# 5  toyota  Green         62008.125      4   4500     22.047333
# 6   honda   Blue         28561.250      4   7500      6.093067
# 7   honda   Blue         34211.250      4   7000      7.819714
# 8  toyota  White         37500.000      4   6250      9.600000
# 9  nissan  White         19750.000      4   9700      3.257732
